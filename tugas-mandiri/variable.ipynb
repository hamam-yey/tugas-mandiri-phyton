# %%
#latihan 1

# = untuk memberi nilai untuk sebuah wadah 
# == untuk mengecek isi sebuah wadah jika benar true dan false jika salah

# %%
#Latihan 2
# c) 2x (karena tidak bisa diawali dengan angka)

# %%
#Latihan 3
angka_favorit = input("Masukkan angka favoritmu: ")
hasil = angka_favorit * 2
print(hasil)
# Out:
# 10101010

# %%
#Latihan 4
alas_segitiga = input("Masukkan alas segitiga : ")
angka_alas_segitiga = int(alas_segitiga)
tinggi_segitiga = input("Masukkan tinggi segitiga : ")
angka_tinggi_segitiga = int(tinggi_segitiga)
luas_segitiga = 0.5 * angka_alas_segitiga * angka_tinggi_segitiga
print(luas_segitiga)
# Out:
# 50.0

# %%
#latihan 6

angka      = 42
desimal    = 3.14
teks       = "Halo Python!"
benar      = True

print(type(angka))
print(type(desimal))
print(type(teks))
print(type(benar))

#1. int 2. float 3. string 4. boolean
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#Latihan 6

angka1 = input("Masukkan angka pertama: ")
angka_pertama = int(angka1)
angka2 = input("Masukkan angka kedua: ")
angka_kedua = int(angka2)
jumlah = angka_pertama + angka_kedua
print("Jumlahnya adalah:", jumlah)


#tipe data belum diubah harus ditambah pengubahnya terlebih dahulu
# Out:
# Jumlahnya adalah: 88
