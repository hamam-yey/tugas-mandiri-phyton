# %%
#Soal 1 = Uner cukup satu operan | biner harus 2 operan
#contoh biner
b = 6
m = 7
print(m + b)
#contoh uner
x = 4
x -= 1
print(x)
# Out:
# 13
# 3

# %%
#Soal 2 = boolean
p = 10 > 5
print(p)
# Out:
# True

# %%
#Soal 3 
#print(True and False) = False
#print(True or False) = True
#print(not True) = False
#print((5 > 3) and (10 < 20)) = True
#print((5 > 3) and (10 > 20)) = False

print(True and False)
print(True or False)
print(not True)
print((5 > 3) and (10 < 20))
print((5 > 3) and (10 > 20))
# Out:
# False
# True
# False
# True
# False

# %%
#Soal 4 
#print("Apple" < "Banana") = True, True karena jika sama sama uppercase maka disesuaikan dengan urutan alfabet
print("Apple" < "Banana")
# Out:
# True

# %%
#Soal 5
#poin = 100
#poin =+ 50  # Seharusnya bagaimana?
#print(poin)

poin = 100
poin += 50  # Seharusnya bagaimana?
print(poin)
# Out:
# 150

# %%
#soal 6
detik = 24 * 60 * 60
print(f"Total detik dalam satu hari:{detik}")
# Out:
# Total detik dalam satu hari:86400

# %%
#Soal 7
nama = input("masukkan nama: ")
input_nilai_ujian = input("masukkan nilai ujian: ")
nilai_ujian = float(input_nilai_ujian)
input_nilai_rata2kelas = input("masukkan nilai rata-rata kelas ")
nilai_rata2kelas = float(input_nilai_rata2kelas)
selisih = nilai_ujian - nilai_rata2kelas
print("    === Laporan nilai ===")
print(f"Nama =             {nama}")
print(f"Nilai ujian =      {nilai_ujian}")
print(f"Rata-rata kelas =  {nilai_rata2kelas}")
print(f"Selisih =          {selisih}")
# Out:
#     === Laporan nilai ===
# Nama =             Budi
# Nilai ujian =      87.5
# Rata-rata kelas =  75.0
# Selisih =          12.5
