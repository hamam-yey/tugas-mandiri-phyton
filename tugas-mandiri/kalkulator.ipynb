# %%
print("Nilai rata-rata:", (80 + 90 + 85) / 3)
# Out:
# Nilai rata-rata: 85.0

# %%
print("=== Hasil Kalkulator ===")
print("\t10 + 5 =", 10 + 5)
print("\t10 - 5 =", 10 - 5)
print("\t10 * 5 =", 10 * 5)
print("\t10 / 5 =", 10 / 5)
print("========================")
# Out:
# === Hasil Kalkulator ===
# 	10 + 5 = 15
# 	10 - 5 = 5
# 	10 * 5 = 50
# 	10 / 5 = 2.0
# ...
